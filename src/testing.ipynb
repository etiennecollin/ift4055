# %%
from utils import *

# %%
# Generate the PDF function
generator = DataGenerator()
function = generator.random_gaussian_mixture_pdf()
generator.plot(function)

# %%
import torch
torch.log(torch.tensor(0))
# Out:
# tensor(-inf)
